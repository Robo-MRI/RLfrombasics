# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# %%
#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98
n_rollout     = 10

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class ActorCritic(nn.Module):
    def __init__(self):
        super(ActorCritic, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(4,256)
        self.fc_pi = nn.Linear(256,2)
        self.fc_v = nn.Linear(256,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    def pi(self, x, softmax_dim = 0):
        x = F.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim=softmax_dim)
        return prob
    
    def v(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_v(x)
        return v
    
    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, done_lst = [], [], [], [], []
        for transition in self.data:
            s,a,r,s_prime,done = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r/100.0])
            s_prime_lst.append(s_prime)
            done_mask = 0.0 if done else 1.0
            done_lst.append([done_mask])
        
        s_batch = torch.tensor(s_lst, dtype=torch.float).to(device) 
        a_batch = torch.tensor(a_lst).to(device)
        r_batch = torch.tensor(r_lst, dtype=torch.float).to(device)
        s_prime_batch = torch.tensor(s_prime_lst, dtype=torch.float).to(device)
        done_batch = torch.tensor(done_lst, dtype=torch.float).to(device)
        
        self.data = []
        return s_batch, a_batch, r_batch, s_prime_batch, done_batch
  
    def train_net(self):
        s, a, r, s_prime, done = self.make_batch()
        td_target = r + gamma * self.v(s_prime) * done
        delta = td_target - self.v(s)
        
        pi = self.pi(s, softmax_dim=1)
        pi_a = pi.gather(1,a)
        loss = -torch.log(pi_a) * delta.detach() + F.smooth_l1_loss(self.v(s), td_target.detach())

        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()

# %%
def main():
    env = gym.make('CartPole-v1')
    model = ActorCritic().to(device)
    print_interval = 20
    score = 0.0

    for n_epi in range(10000):
        done = False
        s, _ = env.reset()
        s = torch.from_numpy(s).float().to(device)
        while not done:
            for t in range(n_rollout):
                prob = model.pi(s)
                m = Categorical(prob)
                a = m.sample().item()
                s_prime, r, done, truncated, info = env.step(a)
                s_prime = torch.from_numpy(s_prime).float().to(device)
                model.put_data((s.cpu().numpy(),a,r,s_prime.cpu().numpy(),done))
                
                s = s_prime
                score += r
                
                if done:
                    break                     
            
            model.train_net()
            
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {:.1f}".format(n_epi, score/print_interval))
            score = 0.0
    env.close()

# %%
if __name__ == '__main__':
    main()
# Out:
# # of episode :20, avg score : 25.9
# # of episode :40, avg score : 16.8
# # of episode :60, avg score : 20.9
# # of episode :80, avg score : 24.7
# # of episode :100, avg score : 18.6
# # of episode :120, avg score : 22.9
# # of episode :140, avg score : 17.6
# # of episode :160, avg score : 17.0
# # of episode :180, avg score : 17.6
# # of episode :200, avg score : 16.5
# # of episode :220, avg score : 16.6
# # of episode :240, avg score : 19.2
# # of episode :260, avg score : 20.8
# # of episode :280, avg score : 23.3
# # of episode :300, avg score : 16.6
# # of episode :320, avg score : 26.7
# # of episode :340, avg score : 23.8
# # of episode :360, avg score : 25.6
# # of episode :380, avg score : 26.0
# # of episode :400, avg score : 29.8
# # of episode :420, avg score : 38.2
# # of episode :440, avg score : 36.5
# # of episode :460, avg score : 35.9
# # of episode :480, avg score : 39.6
# # of episode :500, avg score : 36.2
# # of episode :520, avg score : 39.9
# # of episode :540, avg score : 46.0
# # of episode :560, avg score : 67.6
# # of episode :580, avg score : 53.0
# # of episode :600, avg score : 69.3
# # of episode :620, avg score : 87.0
# # of episode :640, avg score : 103.4
# # of episode :660, avg score : 99.3
# # of episode :680, avg score : 109.8
# # of episode :700, avg score : 110.8
# # of episode :720, avg score : 125.0
# # of episode :740, avg score : 169.4
# # of episode :760, avg score : 141.2
# # of episode :780, avg score : 149.2
# # of episode :800, avg score : 214.8
# # of episode :820, avg score : 209.8
# # of episode :840, avg score : 240.8
# # of episode :860, avg score : 179.7
# # of episode :880, avg score : 268.9
# # of episode :900, avg score : 169.1
# # of episode :920, avg score : 225.1
# # of episode :940, avg score : 284.3
# # of episode :960, avg score : 330.1
# # of episode :980, avg score : 224.3
# # of episode :1000, avg score : 207.1
# # of episode :1020, avg score : 296.2
# # of episode :1040, avg score : 234.7
# # of episode :1060, avg score : 317.9
# # of episode :1080, avg score : 395.0
# # of episode :1100, avg score : 312.2
# # of episode :1120, avg score : 222.4
# # of episode :1140, avg score : 236.4
# # of episode :1160, avg score : 429.9
# # of episode :1180, avg score : 387.4
# # of episode :1200, avg score : 448.8
# # of episode :1220, avg score : 474.8
# # of episode :1240, avg score : 407.1
# # of episode :1260, avg score : 535.2
# # of episode :1280, avg score : 662.5
# # of episode :1300, avg score : 456.3
# # of episode :1320, avg score : 481.4
# # of episode :1340, avg score : 463.2
# # of episode :1360, avg score : 368.6
# # of episode :1380, avg score : 476.6
# # of episode :1400, avg score : 653.5
# # of episode :1420, avg score : 654.2
# # of episode :1440, avg score : 488.6
# # of episode :1460, avg score : 539.6
# # of episode :1480, avg score : 433.6
# # of episode :1500, avg score : 393.6
# # of episode :1520, avg score : 481.7
# # of episode :1540, avg score : 428.5
# # of episode :1560, avg score : 321.7
# # of episode :1580, avg score : 345.3
# # of episode :1600, avg score : 563.8
# # of episode :1620, avg score : 700.5
# # of episode :1640, avg score : 723.7
# # of episode :1660, avg score : 662.1
# # of episode :1680, avg score : 522.4
# # of episode :1700, avg score : 763.6
# # of episode :1720, avg score : 599.9
# # of episode :1740, avg score : 354.4
# # of episode :1760, avg score : 512.0
# # of episode :1780, avg score : 587.6
# # of episode :1800, avg score : 279.4
# # of episode :1820, avg score : 238.6
# # of episode :1840, avg score : 388.9
# # of episode :1860, avg score : 456.1
# # of episode :1880, avg score : 274.1
# # of episode :1900, avg score : 317.9
# # of episode :1920, avg score : 482.1
# # of episode :1940, avg score : 867.5
# # of episode :1960, avg score : 1139.8
# # of episode :1980, avg score : 1438.7
# # of episode :2000, avg score : 517.0
# # of episode :2020, avg score : 817.5
# # of episode :2040, avg score : 836.9
# # of episode :2060, avg score : 925.2
# # of episode :2080, avg score : 377.4
# # of episode :2100, avg score : 319.9
# # of episode :2120, avg score : 302.1
# # of episode :2140, avg score : 359.4
# # of episode :2160, avg score : 548.4
# # of episode :2180, avg score : 806.0
# # of episode :2200, avg score : 614.2
# # of episode :2220, avg score : 332.9
# # of episode :2240, avg score : 321.0
# # of episode :2260, avg score : 365.0
# # of episode :2280, avg score : 455.1
# # of episode :2300, avg score : 466.1
# # of episode :2320, avg score : 374.6
# # of episode :2340, avg score : 290.3
# # of episode :2360, avg score : 488.8
# # of episode :2380, avg score : 327.5
# # of episode :2400, avg score : 454.8
# # of episode :2420, avg score : 525.5
# # of episode :2440, avg score : 559.5
# # of episode :2460, avg score : 280.5
# # of episode :2480, avg score : 217.6
# # of episode :2500, avg score : 556.4
# # of episode :2520, avg score : 939.8
# # of episode :2540, avg score : 1804.7
# # of episode :2560, avg score : 3635.4
# # of episode :2580, avg score : 1142.8
# # of episode :2600, avg score : 1150.8
# # of episode :2620, avg score : 298.2
# # of episode :2640, avg score : 386.6
# # of episode :2660, avg score : 417.7
# # of episode :2680, avg score : 382.9
# # of episode :2700, avg score : 259.9
# # of episode :2720, avg score : 353.9
# # of episode :2740, avg score : 381.5
# # of episode :2760, avg score : 467.9
# # of episode :2780, avg score : 643.2
# # of episode :2800, avg score : 455.3
# # of episode :2820, avg score : 490.2
# # of episode :2840, avg score : 741.0
# # of episode :2860, avg score : 443.4
# # of episode :2880, avg score : 414.6
# # of episode :2900, avg score : 417.0
# # of episode :2920, avg score : 340.9
# # of episode :2940, avg score : 317.9
# # of episode :2960, avg score : 373.8
# # of episode :2980, avg score : 1092.0
# # of episode :3000, avg score : 1455.2
# # of episode :3020, avg score : 507.1
# # of episode :3040, avg score : 1880.5
